# %%
import numpy as np
import tensorflow as tf
from scipy.stats import random_correlation
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ## Multidimensional Geometric Brownian Motion

# %%
T = 20 # time horizon
dt = 1/252 # discretisation
n = 10 # number of assets
N = 1000 # sample size on simplex

NT = int(T/dt) # time
grid = np.linspace(0,T,NT+1) # time grid

S0 = 100*np.ones(n) # initial prices
mu = 0.07*np.ones(n) # drifts
sigma = 0.25*np.ones(n) # volas

eig = np.random.uniform(0.1, 1, n) # 
eig = eig/np.sum(eig)*n # Sum of eigenvalues must equal dimensionality.
rho = random_correlation.rvs(eig) # 
Cov = np.tensordot(sigma, sigma, 0) * rho

# %%
def GBMsimulator(seed, n, S0, mu, sigma, Cov, T, NT):
    if seed:
        np.random.seed(seed) 
    A = np.linalg.cholesky(Cov)
    dW = np.random.normal(size = (n,NT)) * np.sqrt(dt)
    S = np.zeros([n, NT+1])
    S[:, 0] = S0
    for i in range(NT):    
        drift = (mu - 0.5 * sigma**2) * dt
        diffusion = np.matmul(A, dW[:,i])
        S[:, i+1] = S[:, i]*np.exp(drift + diffusion)
    return S.T

S = GBMsimulator(None, n, S0, mu, sigma, Cov, T, NT)
plt.plot(grid,S)
plt.grid()

# %% [markdown]
# ## Cover's Universal Portfolio
# is as good as the long run yield of the best retrospectively chosen constant rebalanced portfolio.

# %%
# Simple market 
n = 2
S_simple = np.ones([NT+1,2])
for i in range(NT+1):
    if i%2 == 0:
        S_simple[i] = np.array([100,100])
    else:
        S_simple[i] = np.array([100,200])
S_simple = np.array(S_simple)
plt.plot(grid[:20],S_simple[:20])
plt.grid()

# %%
# BS model
def BSsimulator(seed, n, S0, mu, sigma, Cov, T, NT):
    S_bm = GBMsimulator(seed, n-1, S0, mu, sigma, Cov, T, NT)
    S_bond = np.ones([NT+1,1])*S0[0]
    S_BM = np.concatenate([S_bm,S_bond],axis = 1)
    return S_BM
S_BM = BSsimulator(None, 11, S0, mu, sigma, Cov, T, NT)
plt.plot(grid[:20],S_BM[:20])
plt.grid()

# %%
def wealth_update(weights,S):
    Vs = np.ones(NT+1)
    for i in range(NT):
        Rt = S[i+1]/S[i]
        Vs[i+1] = Vs[i] * (weights[i] * Rt).sum()
    return Vs

# %%
def compare_strategy(n,S):
    Vsingle = np.max(S[-1]/S[0])
    print('best single: ',Vsingle)

    # equal weight 
    # weight = np.zeros(n)
    # weight[2] = 1
    weight = np.ones(n)/n
    weights = np.tile(weight,[NT,1])
    V = wealth_update(weights,S)
    Vconstant = V[-1]
    print('equally weighted: ',Vconstant)

    # uniform strategies
    simplex_uniform = np.random.exponential(scale=1.0, size=[N,n])
    simplex_uniform = simplex_uniform / np.sum(simplex_uniform,axis=-1,keepdims = True)
    Vuniform = []
    for j,weight in enumerate(simplex_uniform):
        weights = np.tile(weight,[NT,1])
        V = wealth_update(weights,S)
        Vuniform.append(V)
    Vuniform = np.array(Vuniform)
    
    # best constant rebalanced portfolio strategy
    Vbest = np.max(Vuniform[:,-1])
    print('best: ',Vbest)
    
    # adapted strategy 
    weights = np.ones([NT,n])/n
    for i in range(1,NT):
        weights[i] = np.mean(simplex_uniform*Vuniform[:,i,None],axis=0) / np.mean(Vuniform[:,i])
    V = wealth_update(weights,S)
    Vadapted = V[-1]
    print('adaptive rebalanced: ',Vadapted)
    
    return Vsingle, Vconstant, Vbest, Vadapted

# %%
Vsingle, Vconstant, Vbest, Vadapted = compare_strategy(2,S_simple)
# Out:
# best single:  1.0
# equally weighted:  8.023365328216683e+128
# best:  8.023363584142e+128
# adaptive rebalanced:  3.8864638424735975e+127

# %%
Vsingle, Vconstant, Vbest, Vadapted = compare_strategy(11,S_BM)
# Out:
# best single:  33.25222164581589
# equally weighted:  5.667051806417427
# best:  16.81633358037434
# adaptive rebalanced:  5.772930361888152

# %%
trials = 10
def test(trials):
    Vsingle_list = np.zeros(trials)
    Vconstant_list = np.zeros(trials)
    Vbest_list = np.zeros(trials)
    Vadapted_list = np.zeros(trials)
    for trial in tqdm(range(trials)):
        print('='*100)
        print('Trial number: ',trial)
        S_BM = BSsimulator(None, 11, S0, mu, sigma, Cov, T, NT)
        Vsingle, Vconstant, Vbest, Vadapted = compare_strategy(11,S_BM)
        Vsingle_list[trial] = Vsingle
        Vconstant_list[trial] = Vconstant
        Vbest_list[trial] = Vbest
        Vadapted_list[trial] = Vadapted
    return Vsingle_list, Vconstant_list, Vbest_list, Vadapted_list
Vsingle_list, Vconstant_list, Vbest_list, Vadapted_list = test(10)
# Out:
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
# ====================================================================================================
# Trial number:  0
# best single:  33.672288652729264
# equally weighted:  4.573682287213423
#  10%|████▍                                       | 1/10 [00:07<01:03,  7.10s/it]
# best:  14.513557228976127
# adaptive rebalanced:  4.828267213804363
# ====================================================================================================
# Trial number:  1
# best single:  13.750199614987327
# equally weighted:  4.766430532280751
#  20%|████████▊                                   | 2/10 [00:14<00:56,  7.05s/it]
# best:  11.845267906049171
# adaptive rebalanced:  4.814243775470068
# ====================================================================================================
# Trial number:  2
# best single:  3.2011983895699165
# equally weighted:  2.549113791412452
#  30%|█████████████▏                              | 3/10 [00:21<00:49,  7.09s/it]
# best:  3.9988190987820342
# adaptive rebalanced:  2.496225174269032
# ====================================================================================================
# Trial number:  3
# best single:  8.329847901212863
# equally weighted:  3.7809116412624344
#  40%|█████████████████▌                          | 4/10 [00:28<00:42,  7.09s/it]
# best:  6.657880904164148
# adaptive rebalanced:  3.74472981464798
# ====================================================================================================
# Trial number:  4
# best single:  21.676801327904503
# equally weighted:  2.678098683018241
#  50%|██████████████████████                      | 5/10 [00:35<00:35,  7.11s/it]
# best:  9.113754422618975
# adaptive rebalanced:  2.7351539039603074
# ====================================================================================================
# Trial number:  5
# best single:  27.225984151800322
# equally weighted:  3.5512724491840597
#  60%|██████████████████████████▍                 | 6/10 [00:42<00:28,  7.12s/it]
# best:  10.578859226998409
# adaptive rebalanced:  3.600988513744976
# ====================================================================================================
# Trial number:  6
# best single:  10.22689511915366
# equally weighted:  2.9805936443484327
#  70%|██████████████████████████████▊             | 7/10 [00:49<00:21,  7.11s/it]
# best:  7.318939843392004
# adaptive rebalanced:  2.949634612367931
# ====================================================================================================
# Trial number:  7
# best single:  11.353522269826655
# equally weighted:  4.018513201211071

# %%
plt.scatter(np.arange(trials),np.log(Vsingle_list)/T,label = 'single')
plt.scatter(np.arange(trials),np.log(Vconstant_list)/T,label = 'constant')
plt.scatter(np.arange(trials),np.log(Vadapted_list)/T,label = 'adapted')
plt.scatter(np.arange(trials),np.log(Vbest_list)/T,label = 'best')
plt.legend()
plt.grid()

# %% [markdown]
# ## The Market Portfolio
# from Fernholz Stochastic Portfolio Theory, where rebalancing rule need not to be constant anymore but may depend on the present state of
# the stock market

# %% [markdown]
# ## Log-optimal Numeraire Portfolio
# not model-free but for comparision
